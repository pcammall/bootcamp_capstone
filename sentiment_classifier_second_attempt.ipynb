# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.model_selection import train_test_split

import re
import string
import nltk
from nltk.stem import WordNetLemmatizer

# %%
#input_data = pd.read_csv(r'C:\Users\Patrick\Documents\GitHub\bootcamp_capstone\kaggle_dataset\sentiment_analysis_financial_news\all-data.csv'
#                , encoding = "ISO-8859-1", header=None, names=['sentiment', 'text'])

input_data = pd.read_csv(r'C:\Users\Patrick\Documents\GitHub\bootcamp_capstone\kaggle_dataset\stock-market_sentiment\stock_data.csv',
                        encoding="ISO-8859-1", header=1, names=['text', 'sentiment'] )

input_data.head(100)
# Out:
#                                                  text  sentiment
# 0   user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 1   user I'd be afraid to short AMZN - they are lo...          1
# 2                                   MNTA Over 12.00            1
# 3                                    OI  Over 21.37            1
# 4                                   PGNX  Over 3.04            1
# ..                                                ...        ...
# 95  NG nhod - what do you see? check the weekly - ...          1
# 96  AIG American International Group Option Trader...         -1
# 97                                 P out balance +.32          1
# 98                                VNG buys vs. Sells?          1
# 99  BAC In  12.00 since there is consolidation  th...          1
#
# [100 rows x 2 columns]

# %%
#install nltk package
import sys
# !{sys.executable} -m pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\patrick\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: tqdm in c:\users\patrick\anaconda3\lib\site-packages (from nltk) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\patrick\anaconda3\lib\site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: joblib in c:\users\patrick\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in c:\users\patrick\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: colorama in c:\users\patrick\anaconda3\lib\site-packages (from click->nltk) (0.4.4)

# %%
#download the necessary data 
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Patrick\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Data Cleaning
#first, remove stopwords
stopwords = nltk.corpus.stopwords.words('english')
lemmatizer = WordNetLemmatizer()

# %%
#data cleaning preprocessing
pattern = r'[^a-zA-Z0-9\s\%]'
cleaned_buffer = []
for x in input_data['text']:
    temp = re.sub(pattern, " ", x)
    temp = temp.lower()
    temp = temp.split()
    temp = [lemmatizer.lemmatize(word) for word in temp if not word in set(stopwords)]
    temp = ' '.join(temp)
    cleaned_buffer.append(temp)

# %%
cleaned_buffer
# Out:
# ['user aap movie 55% return fea geed indicator 15 trade year awesome',
#  'user afraid short amzn looking like near monopoly ebooks infrastructure service',
#  'mnta 12 00',
#  'oi 21 37',
#  'pgnx 3 04',
#  'aap user current downtrend break otherwise short term correction med term downtrend',
#  'monday relative weakness nyx win tie tap ice int bmc aon c chk biib',
#  'goog ower trend line channel test volume support',
#  'aap watch tomorrow ong entry',
#  'assuming fcx open tomorrow 34 25 trigger buy still much like setup',
#  'really worry everyone expects market rally usually exact opposite happens every time shall see soon bac spx jpm',
#  'aap gamco arry haverty apple extremely cheap great video',
#  'user maykiljil posted agree msft going higher possibly north 30',
#  'momentum coming back etfc broke ma200 resistance solid volume friday ong set',
#  'ha hitting 35 65 mean resume targeting 42 level',
#  'user gameplan shot today liked trend break may c h break oc weekly trend break back july 2011',
#  'fcx gapping well ideal entry looking pull least 35 open entry',
#  'user great list particularly like fisv syk buy hold type check free list',
#  'athx upper trend line',
#  'ng nice pnf breakout need follow thru',
#  'believe aap uptrend back cross 50',
#  'x swing still',
#  'swy 30% float short breaking ouch',
#  'biof want 4 90 comin',
#  'v inverted head shoulder play well able catch entry eye',
#  'red ready break',
#  'ei close breaking trigger 30 40',
#  'user bac quick trade late investing 11 98 good entry point imho',
#  'chdn ong 49 02 trailing stop 56 66 6 prior stop 54 17 49 88 49 82 45 47 43 02 41 92',
#  'aap vome today impressive rate well probably get 30m share traded today',
#  'user adding vxy long bottom today trade also got wpi near low',
#  'repeat global economy going get better year go c instead bac',
#  'goog go ong close 725',
#  'nkd looking like good short failed break price level resistance 116 today',
#  'g like price action far holding 130 still deciding whether go ong call stock',
#  'sbx buy clear resistance 54 5',
#  'new target aap notice shakeout reading 8 49 buy dot monday',
#  'early short move stock market need day settle patience coh bwd dt aap pay',
#  'aap obbers hit apple store paris prefer take merchendise cash bullish',
#  'axa tip day buy even sign newsletter anything wrong eat crow',
#  'x 1 2 due move today kirby daily around 26 00 still swinging 1 2',
#  'aap 10 min short longs fully added look pop market shakeout reset',
#  'ng stellar move still long swing full position believe user user 2',
#  'atice tade setp ko cnx',
#  'idcc 50sma acting good support short term momentum indicator switched upside',
#  'new post bac 19 month high showing sign stress',
#  'c two daily bull flag top bullish still',
#  'ng traditional point figure bullish signal multiyear high',
#  'jpm closed 10sma monday u know rule large cup n handle still bullish',
#  'eog ascending triangle original target 127 extension eps feb 11th 1 2 position swing',
#  'aapl daily broke downtrend closing price w v pattern back play 600 target',
#  'phm pultegroup option bear bet 1 5 million 11% move april',
#  'bac 11 97 trade',
#  'short setup displaying relative weakness ao coh pay bwd dt shd wtw p prepare short stall e f',
#  'amzn monetize electronics make traffic marketplace aap goog wake say buy ebay',
#  'cvi starting clean book making first buy yr entry 49 54 stop 47 43',
#  'sam cheer temporary solution economic woe entry 139 81 stop 131 92',
#  'sk gave',
#  'ovti ttm ending oct 2012 negative 151 million operational cash flow 273% decline v yoy ttm ending oct 2011',
#  'aap goog respond positively good jobless claim number',
#  'analyst price target earnings target coming exacty want see prior aap reporting',
#  'user nice color intc bull well',
#  'head p aa earnings 1 8 13 es week away tho season eay begin cranking til 1 16 w g jpm ebay et al',
#  'trade idea buy wo market 26 64 target 36 cut 23 50',
#  'trade idea buy dc market 58 50 target 67 cut 53',
#  'goog look set make new ath e unknown',
#  'goog trade one long verse 10sma',
#  'fnf ong 19 43 trailing stop 21 04 6 prior stop 19 71 19 52 18 70 18 65 18 07 17 87',
#  'fod see solid move tom system predict nice green candle',
#  'year fitness health apps winner gynormous speculation run high nke',
#  'time invest msft compq',
#  'new post short make dime ongs make dollar aap spx qqq p',
#  'nbelieveable payment trend vc chasing easily played public market ebay v mastercard time high',
#  'watch list stock triggered today oex agnx tv vbd xide ppc exp onty bmn f wk chmt fbc isi aig',
#  'nice bull flag breakout oc technology software',
#  'setup alert went bonkers today one many got triggered cup handle breakout pfe',
#  'host congrats cloud today ax user time high wow',
#  'x steel breakout mt',
#  'dndn broken clear 5 5 resistanc level heavy volume could headed much higher',
#  'expe look good higher price',
#  'apc weekly setting long',
#  'going morning long 3 aap 560 call option goog 725 call jan 4th expiration',
#  'e f path higher unthreatened unless 1452 25 support fails see resistance 1466 00 spx stock',
#  'monitor line price dynamic stock closed dec 28 line new high be4 price mho tsm ipgp eqix bc bdc ash',
#  'ddd idcc continue higher',
#  'hoped pick ost today look like day late nice move morning',
#  'gps wow wa fast fast fade',
#  'amzn going 260 go near 300 market behaves week',
#  'huston geen aap',
#  'p long 9 55',
#  'hn breakout 3rd day look pullback enter long',
#  'ng ascend triangle much like f x breakout 127 exten 161 8 target fib subjective',
#  'kcg thing make go hmmmm',
#  'vng huge news patent attorney dan avicher',
#  'ng nhod check weekly target previous low 2006',
#  'ng nhod see check weekly target previous low 2006',
#  'aig american international group option trader bet 4% move next friday',
#  'p balance 32',
#  'vng buy v sell',
#  'bac 12 00 since consolidation level could close 12 09 market stable pm imho',
#  'vng parabolic move comin',
#  'new sony pre owned block tech patent unearthed sne 50% gme profit pre owned last one turn light',
#  'liked v love wynn 111 entry new target yesterday 121 nice',
#  'user spx 1464 90 wave iv would 20 point lower 1467 00 key e f hod 1460 00 neckline 1458 50 bearish',
#  'ddd consolidating strong move previous day 55 60 next buy point 60 volume holding',
#  'vng 12 mil share short plus long buying massive vng short squeeze thought story dead avicher kill short thesis',
#  'wow good bk user sale nook 13% holiday',
#  'ac watch list volume pick 139% full day average 200 day bounce',
#  'new wightwatchers ad fun light regular people interesting still dont trust wtw position',
#  'amzn holding well next buy point clear upper trend line heavy volume',
#  'exactly want see follow thru day breaking new high volume',
#  'zcs user buying',
#  'aap spy qe 2013 bring geithner',
#  'extended stock market unexpected news fed minute esd panicky e f nq f',
#  'spy ncle ben needed spice thing little aap people bored wake',
#  'aap might close low day bear control descending trendline watch',
#  'fan seeking 200d im adding synthetic short add 200d',
#  'cwst low day 4 50 near high day 4 56 watchn b minimal risk',
#  'gme gamestop short target spy',
#  'time get cloud stock vmw cm',
#  'bac keep overniight mmy po bin premarket tmorrow',
#  'polk expects 2013 new vehicle egistrations 15 3 million polk f gm think low',
#  'bullish market also talked trend scty ost angi fio panw jcp p yep mnst gpn show',
#  'bac happens next',
#  'kcg someone bought 3 22k 4 jan 18 call',
#  'man didnt know skippy made would thrown jar h hormel',
#  'big move bond today 7 month high 10 rate still going lower zn f could get truly ugly good nfp number spy tt',
#  'market wrap video addition watch ist including bcei bji cee e son sqnm nx yep',
#  'maybe vrng asked judge 7% royalty became risky goog deal want settle',
#  'bji 35 53 good volume',
#  'cee 35 12',
#  'sqnm 5 05',
#  'nx flag break',
#  '3d system brings next gen consumer 3d printing ce 2013 ddd',
#  'aap top april aston kutcher star job kinda like facebook social network came fb',
#  'vng w macd turning signal line vng could post nice rally current level',
#  'pi 3q 10q operational cash flow 9mos 20million 269%decline v 9mos year ago',
#  'bbby 3q 10q operational cash flow 135 million 53 increase v year ago q3 64% improvement q q',
#  'di 6mos operational cash flow 267 million increase 187 million v 6mos year ago 233% increase',
#  '3q 10q 9mos operational cash flow 32 million v neg 26 mil 9mos year ago',
#  '3q operational cash flow neg 16 million v year ago 3q negative 68million 52 million improvement',
#  'quiet carl icahn bullish nfx short paranoid every close get acquired think aapl msft amzn fb',
#  'aapl bull cannot break trend line obv',
#  'user phantom7 calling 4 ever since start thing 3 75 given kcg',
#  'nx watch list small flag volume 26% ave full day good volume',
#  'goog poised clear next resistance buy add area watch action volume closely',
#  'gdp watch list slightly line 50 day ema light volume 5% ave full day',
#  'took profit ddd add break 60 volume',
#  'chk looking small risk position call scalp maybe swing xe watch',
#  'onty holder would hold raise ask could really pop going climb slowly regardless',
#  'eog pxd oas energyswag',
#  'aap moving volume couldnt cope descending trend line trend still perhaps 460 impossible',
#  'aap 50ema continue work aap making lower high maco sense',
#  'went short spy yesterday picked aap instead still think market need move bit resume move upside',
#  'aap people realistic market undecided apple earnings lift cloud good might eay see reversal',
#  'watch close carefully decide whether ong shot aap 530 shot',
#  'jcp keep eye triangle big short int 34% report feb 27 cup handle dt ong',
#  'sold little goog first time',
#  'nice cup handle breakout mca',
#  'faf new high',
#  'spy giving aap finger care anymore lol',
#  'smith corona ok amzn',
#  'va ong 43 07 trailing stop 58 98 11 stop 54 53 52 45 48 05 47 32 46 71 41 32 39 57',
#  'amzn alert update last minute push tried shake put hanging',
#  'aap volume higher today monday keep mind',
#  'hb ong 73 67 trailing stop 71 92 3 prior stop 70 86 68 64 62 41',
#  'key panic aap domain twitchy day trader robot long term hold fundamental',
#  'nvda 4 hour love see vol explode',
#  'vng take hard look goog ftc settlement patent ftc making goog play nice vng make sense',
#  'worried gone oco 737 71 call goog door step nearly 40 move',
#  'vng crazy anyone listens trade tool',
#  'goog getting fueled aap reversal',
#  'user make bby offer shave 4 offer price bid went 24 26 20 matter month',
#  'nvda answer question entry add red candle 10 50am today ove flag',
#  'aap 950 lot bid feb 580 call 9 50 might push stock create support 26 delta option',
#  'wpi short candidate list 12 31 missed got started short today',
#  'mye breaking',
#  'short ht 200 sma stop high day first target 53 95 second target 53 21 gap fill',
#  'qcom introduces streamboost average home connects seven device internet',
#  'nvda love see momo next week like previous histogram bar noted',
#  'hma unusual option activity trader buy 11k jan 9 put short term bear play',
#  'adbe option trader buy 5 300 feb 39c oi 741 bet stock 39 feb 16th',
#  'nvda ooks bullish must stay 13 05 closing basis monthly eps say',
#  'sqnm watch list line volume 86% ave full day',
#  'hott failed breakout',
#  'zn f ticking seller sdjpy already',
#  'ino wow nice accumulation today heavy',
#  'znga fat juicy short back lower level close gap 2 72',
#  'gdot nice bounce 50sma ooks ready test recent high',
#  'hma ooking 10 headed higher',
#  'spf ooking 9 headed higher lower rate',
#  'g jpm xf hod hungry stock spy',
#  'chk weekly bullish engulfing',
#  'g look good heading next week',
#  'aap know ipad mini stock everywhere going 8 different store none em stock',
#  'goog explodes aapl implodes minte 21 23 user vid year ago mark nailing subject',
#  'kkd krispy kreme doughnut inc ic xchange conference ive 01 17 13 9 15 et',
#  'picked f pullback due downgrade held support close week first pt 37 30',
#  'user picking one calling kkd next food company make dpz like run twenty13',
#  'znga still show red dead enko view pf box size 0 25',
#  'g enko view g pf box size 5 showing potential break 175',
#  'nvda enko view showing red dead need 14 long le 13 short',
#  'csx enko view pf box size 1 vey bullish 21 coal stock confirming move rail',
#  'goog enko w pf box size 50 look like failed breakout',
#  'user 155 g bullish fin rate low fed put',
#  'user znga use lagging indicator lagging stock',
#  'goog like close 744 96',
#  'f b bull flag heavy vol etest support today light vol 41% short float',
#  'msft gap close continues base si rising nice pickup w stop major support 28 22 pt',
#  'financials continue ripping easy money c approaching 43 pt',
#  'v follow throughs 10 dma crossing 200 dma trading great setup',
#  'user bac yeah made easy profit slashing job close win win sale',
#  'new buy today watch list well nx 20% son yep bcei gdp ay sqnm total trigger week 39 big week',
#  'sbx si earththis kind stuff make u perk sorry go bullish five wave 58',
#  'say brainier ong sbac stock 60 80 feb collar protection',
#  'anyone say much svu would go even deal go 4 5 sure much upside left',
#  'nvda bounce continues stock cleared 200sma 13 level ong',
#  'axti momentum picking w macd climbing si rising obv indicator made new higher high week',
#  'gdot obv moving upwards mean big money moving stock slowly ong',
#  'aapl daily see note',
#  'amzn daily see note',
#  'c daily see note',
#  'egov long 16 62 strong resting basing room upper bolly absorb 10 20 day atr',
#  'aa fib friend',
#  'tsa judge dismisses massachusetts state automobile dealer association awsuit',
#  'bac trending appear slow yet prudent take profit time',
#  'fe look like fired sell signal friday may trade short tick friday low work utility later',
#  'coh also got rejected cloud still slight uptrend past buy enters cloud',
#  'yum look good cloud stop either 200 sma cloud target 50 sma',
#  'eqix expe fb g hog mon pii qcom qih soda idea next week favorite setup eqix',
#  'eqix position would like see breakout 216 50 prefer consolidation though',
#  'time contraction aap test 500 week wed long jan11th 510 500 put spread',
#  'aap bounce coming',
#  'f en fuego',
#  'axa sold oscillating ange indicator suggest buy price hold prev close increase volume',
#  'holding check user bullish macd cross bbg cop eni eog jec ig sfy xe xop',
#  'jds beautiful trend 13 5 bring dip buyer',
#  'ko trouble staying 200 day sma past week could short higher stop 38',
#  'mako red day monday break support could test old low 9 9 25',
#  'hour advanced opt mako fod gnmk jds ege amn px aay ddd sv pm bk f',
#  'goog simple fibonacci projection close 739 127 2% 766 161 8% 802',
#  'buying aap monday',
#  'user amzn 263 measured move 307',
#  'user ino pipeline partnership ni mk pretty much sum',
#  'amzn data company retailer new post',
#  'trading environment favor long side stay welcome quality leader g amh ocn egn hov aap',
#  'aap amazing run since 2005 think',
#  'tale two stock aap goog spy qqq',
#  'f ford powerful bullish pattern dictate price direction',
#  'dt descending triangle ower high participate well rally overbought',
#  'cva 19 00',
#  'mck 100 05',
#  'vmed know prefer 3 4 day pullback reverse maybe mon tuesday flag break sup',
#  'kidding legible version currently long f tweeted friday',
#  'ford perform well due hurricane sandy destruction f palladium well pa bank buy pick bac c san g',
#  'g buy pullback 133 bigger pullback 130',
#  'ceg keep watch list',
#  'wish tv would die already like newspaper told cbs ftw',
#  'think aap heading back check 506 support',
#  'amzn yap yap yap',
#  'sndk pattern looking interesting successfully break gap time around',
#  'amzn time high pre market aapl still plunging interesting trading day',
#  'see risk e f 1442 00 1423 75 bearish momentum divergence resolve spx spy stock',
#  'user onxx strong price vol expansion friday possibly looking higher price another biotech 2 level',
#  'znga momentum building upside watch',
#  'e watch list also fast move today volume 77% ave full day usually tiny volume',
#  'twi like long 24% short',
#  'green weekly triangle heo pdating',
#  'eog 60 min pullback breakout watching 1 2 position',
#  'kcg 3 75',
#  'zcs almost hit stop loss glad see heading back',
#  'aap closed short nice gain',
#  'v beautiful uptrend since june 12 never broke higher high higher low trend',
#  'awesome aap trendline ever since 1986',
#  'ddd ong 27 95 trailing stop 42 35 7 prior stop 41 70 39 03 36 53 32 35 27 95 25 44 22 93',
#  'nx largest watch list gainer new buy friday biggest mover today protect gain',
#  'green weekly triangle ktos pdating',
#  'ak corrected pphm largest watch list gainer today though gapped big open',
#  'aap positive close 530 today bullish looking possible ong set',
#  'ceg possible ong today want play jpmogan biotech conference',
#  'fme ong 10 25 trailing stop 13 75 8 prior stop 12 29 11 50 10 97 10 63 10 36 9 64 9 03',
#  'showed friday upside orange dot traget 517 hit morn red dot',
#  'triggered 34 first target 34 55 90',
#  'sxc breaking key downward channel level ikely move much higher',
#  'must follow young man user amzn data company retailer new post',
#  'pg short back',
#  'ovti downgrade sept 7th 16 77 q1 looking good next filing q3 end feb',
#  'v option trader sell 26k 47 25 52 25 call spread march big bet stock 47 25 march expiry',
#  'aa option trader bet bad earnings selling 6 200 jan 9c buying 3 200 jan 9p could hedge stock trade low oi',
#  'skx q3 operational cash flow negative 60million 80million decline v q3 2011',
#  'skx 9 mo 2012 operational cash flow negative 20 million 95 million decline v 9mos 2011',
#  'ed weekly triangle sn pdating',
#  'bac avrg 12 127',
#  'first trade coming back vacation hot short 59 80 stop 60 30',
#  'green weekly triangle scc pdating',
#  'podd breaking new 52wk high decent base',
#  '3 horseman high beta momo chase f gmc nfx slammed bit advanced tell new year party mrkt',
#  'pna look like solid set',
#  'name buy pullback g ceg fb f',
#  'ba flush',
#  'amazon break 1 600 adjusting split via user amzn',
#  'financials xf driving mkt higher today weak ish except jpm 1st time little red flag 1',
#  'ive broadcast got long signal pcn covered discount buy need push',
#  'amzn vome go big boy grabbing stock higher price come',
#  'twi high seen since september',
#  'user gold 2011 stock contest w v silver 2012 w tkc ddaif call win 2013',
#  'amzn fb pick higher price week breaking considerable volume',
#  'eceryone want piece pcn gorwth magic stake high innovation fast marketing stake high',
#  'user scheplick easy short amzn buy ipad mini tax prep book border ackspace time',
#  'might open position today cup handle make one fly 7 7 5 quickly',
#  'c ko positive nice reversal ko',
#  'axp trying make move getting interesting',
#  'strong follow thru day breaking new high last friday confirmation solid',
#  'v new high looking higher price',
#  'ceg strong breakout new high today 2x daily avg volume ooks good upside',
#  'wetf cheap financial stock trying b would like see pullback consolidation first',
#  'nfx short paranoid every close buyout come 1 night aapl msft goog amzn etc dominate webtv long nflx',
#  'last 3 session last hour buyer back money need put work money flow spy tt e f',
#  'user stock telling u anything new trend saying lot e aap anticipated year',
#  'rax setting spy',
#  'pcn long entry',
#  'green weekly triangle ampe sell short 4 15',
#  'green weekly monthly triangle fws pdating monthly',
#  'user saying zagg another 23%',
#  'green weekly monthly triangle pab pdating',
#  '744 96 great level close goog',
#  'aap short term outlook 3 possible scenario 2 bullish',
#  'barclays upside case csod year end price target 46 based 8x cy 14 revenue 10% upside estimate quite achievable',
#  'ctxs conservative swing bouncing nicely support w volume mcp aggressive swing however strong probability',
#  'user amzn time bird fly south',
#  'vvs technical positive continued climb si obv macd look good',
#  'akx b 13 78 like base action spot declining vol ripe pop',
#  'hao b 7 20 price rejected 7 19 today also high 12 21',
#  'hway b 11 08 nice base spot',
#  'yum premarket cloud support 62 75',
#  'multi day downswing e f favored see demand zone 1442 00 1423 75 spx spy stock',
#  'mon making sale buyer weakness look like game',
#  'fin 9mos operational cash flow decline 15million v prior yr first 9mos 198% decline',
#  'ayi q1 operational cash flow turn negative',
#  'ayi 1st negative operational cash flow quarter since quarter novemebr 2008',
#  'ayi 2013 q1 operational cash flow negative 14 5 million decline 41 million v q1 2012 152% decline',
#  '526 20 bid hit aapl expecting least move 540 today',
#  'mon 2013 q1 operational cash flow 1 569 billion 459 million increase v 2012 q1 41% increase',
#  'fio nothing air stock 17 70 17 80',
#  'aap daily fade motion people want still work',
#  'shorted nfx 1 00 stop',
#  'ctic got long',
#  'catch user hot ink totally hook morning many great read aap maco',
#  'ihs year end operational cash flow declined 27 million v 2011 8 19% decline',
#  'watch xf jpm bac od closely',
#  'unit cost 1 60 see bounce ctic',
#  'little whip pop drop go one purchase avg day limit exposure % portfolio ctic',
#  'shd get short someone big must exiting imo sitting 40 put',
#  'mon added',
#  'like gag new american socialism enjoy video courtesy aig',
#  'jnp added',
#  'x added',
#  'user mr florida hope well trade save past im asking like ooking fill gap',
#  'shd die already ampert know 2 sh t running retail bought sears property',
#  'wn ong 19 79 trailing stop 24 39 6 prior stop 23 76 20 42 19 79 18 09 17 13 16 39',
#  'deck short 66 41 trailing stop 44 16 5 prior stop 51 65 59 07 66 41 74 13 81 85',
#  'wfm short back',
#  'nice base building 1 50 1 54 ctic test hod afternoon setting nicely follow thru tomorrow tradeoftheweek',
#  '16 million share ctic almost 10x avg daily vol think one day story gap 2 05 plenty rm run imho',
#  'shd eddie ampert 1 trick pony',
#  'et angry anecdotal comment begin still think blackberry im doomed imm aap goog nok vz',
#  'user think aap putting long term bottom course could wrong look like',
#  'price alert go www desk',
#  'gg delisted soon typicall pump dump story last month careful one day trade mil next day ur stuck',
#  'tso option trader buy 10k feb 40p 1 60 1 6 million bet stock 40 feb exp could hedge oi 544',
#  'ddd ssy stop honored must become bearshitter',
#  'cybx keep consolidating near time high',
#  'ddd sentiment stock change blink eye faint heart still long term bullish',
#  'mcp bottom 11 00 strong esistance nder level short breakout chance',
#  'aig win awsuit announces dividend reinstatement',
#  'tivo buyout coming sure seems strong late',
#  'biggest mistake made day sticking gut reversal soas 2 sticking watchlist dk stp ana kog',
#  'ddd look easy short',
#  'instinct spot 2013 still think ctic hit 2 05 wk still want stick morning watchlist chase',
#  'ax look good higher price',
#  'cm holding well',
#  'ana conference tomorrow guess hit 10 05',
#  'nfx hearing pjco cautious following comscore data following weak december overall 4q traffic turn negative user',
#  'se pullback 2 initiate quick trade invest long keep stop tight sell aap egn ocn amh ddd nsm',
#  'piper jaffray making negative comment nfx cst ed box comscore q4 data weak edbox netflix',
#  'maybe good time buy td 44 level appears holding key support level',
#  'csn option trader buy 1 500 jan 11 16 call spread low oi indicating entering position 50 bet data bef jan 19',
#  'aa go kid college fund',
#  'x option trader take profit feb26p selling 8k 8k oi rolling position feb 25p buying 8k 1 48',
#  'green monthly triangle acad net profit 7 177 00 11 49%',
#  'far good regarding apo earnings strategy far soon call win though',
#  'aa went',
#  'aa hold key spx aa earnings spx 1 90% mo later',
#  'call week aa wfc apo mon',
#  'aa like spin operational cash flow',
#  'apo q1 2013 operational cash flow 210 million 90million decline v 2012 q1 30% decline',
#  'ed weekly triangle am net profit 26 135 00 38 40%',
#  'cm avg tho amwd coiling breakout new high set buy stop slightly recent high',
#  'user jemberlin number good swing personally hate amd',
#  'spy spx e green hedge star model next stop 1410 56 spx 1387 92 lower',
#  'swhc look like ban large capacity magazine hurdle purchase table politician evening news',
#  'aa q4 operational cf declined 209m v q4 11 18% decine p spin say higher q3 2012 note q3 12 263m le q3 11',
#  'ht closed 200 sma barely 3rd time since oct eps way watch volume 55',
#  'user pwe crazy hao green weekly triangle short long',
#  'wt huge 39 seller today check daily hold 40 42 loooks good swing',
#  'aj 18 00 good volume',
#  'cybx broke time high accompained strong volume suggesting higher level',
#  'onty look poised bounce bottom si starting turn macd crossing signal',
#  'still trading within uptrend channel short term uptrend still intact still bullish nvda',
#  'vvs vivus ceo eportedly say acquisition inevitable talking deal eporter j p morgan',
#  'user c runner',
#  'v one longest growth stock holding ever 19 month counting',
#  'fio bouncing morning 25% short interest still nothing air till 17 90',
#  'tol doji yesterday could mean another lower high wait close cloud going short',
#  'amwd setting nicely 29 33 strong building construction product group along apog',
#  'tab like one real reason new contract picking slack 2013 small cell tech software service',
#  'f buy signal triggered u',
#  'anf radar move 48 70 49',
#  'dgi ftd pivot range 26 98 28 33',
#  'hpq option trader buy 10k aug 13p 78 780k bet stock 13 aug expiration could stock hedge',
#  'faf new high still holding need volume',
#  'n perfect day reversal candle daily',
#  'voc actually triggerd yesterday closed back line today itstrying vol 16%',
#  'added app',
#  'wfm added small 89 prefer 90 91 level lay short',
#  'ma watch list broke flag today also top line volume 11% full day ave',
#  'cmg 5m descending triangle 9% avg volume',
#  'user ddd broke bear flag upside ots short understand momentum caught stdy',
#  'dgi still moving',
#  'ssys maybe share outstanding short 11 million operational cash flow ttm trading 1 9 bil mkt cap',
#  'ssys operational cash flow declined 42% ttm v ttm',
#  'covering 1 2 wac short 47 15 looking lower got book',
#  'vtx option trader buy 3 700 put spread april 48 42 strike could big bet move stock hedge',
#  'f 4 hour nice bounce ichard',
#  'gnc nice inverse head shoulder well nice pullback support previous box breakout',
#  'user hate 3 average end screw good nn',
#  'da nice run entry moving stop breakeven',
#  'ed weekly triangle ctic net profit 675 00 3 88% gly waiting 3 month',
#  'cw clearwire corp arge trade put show bearish interest despite dish bid',
#  'apo strong push support w volume',
#  'watch list hao slipped line watching volume 76% full day ave',
#  'bearish thing seen week good overall market jpm spy e f',
#  'user bullish sell always buy bearish market buy sell nx',
#  'voc watch list added tuesday run 50 day ema vol increased 86%',
#  'ana getting breakout yest holding today presenting jpm conf today 6 30est',
#  'trade idea buy esc 25 95 target 35 50 cut 21 40',
#  'swks decision coming soon expecting break looking si macd tix',
#  'small dose reality ctic',
#  'v option trader close feb 50c selling 12k 22k oi open position feb 55c selling 23k hard bid v oi 2 700',
#  'six year ago apple introduced iphone world remember aapl sixyearsold',
#  'ew went long ew 93 15 ooks like ready make move 98 w breakout consolidation',
#  'ebay basing',
#  'short yhoo',
#  'chk thanks jpm upgraded',
#  'dec 6 bb cm initiated ssys buy 68 wonder still buy 28% 30 day',
#  'user ssys eached si 80% crash near',
#  'ssq pulling back suspected uckily sold near 11 20 re tweeted watching 10 80 get bck',
#  'user day ipo tripled position 42 ipo priced 39 never touched since probably best stock move ever',
#  'aap p f bullish',
#  'aap support broken hesitate sell lot downside favor longs',
#  'user eaders ead bac side question even aap broken since week medium outlook look bright',
#  'green weekly triangle depo scaling 6 40',
#  'intel tobacco stock interesting read analogy intel guess dividend tasty intc',
#  'green weekly triangle fnfg scaling 8 22',
#  'faf ong 16 92 trailing stop 22 31 8 prior stop 22 04 16 92 16 40 15 17 15 10',
#  'swy inside day held 50 sma rsi holding 40 look like counter trend move',
#  'despite weakness aap spy fill 2day gap reversed mere 0 13 away every stock outperforming aap day',
#  'ipx 22 15',
#  '28 25 28 50',
#  'xxia 18 00',
#  'user shot yhoo 0',
#  'wpi buying look counter trend possible bear wedge wont happy close 2 3 day 50sma evaluate',
#  'mon monthly game',
#  'ha eps estimate slashed squeezed stock crash land looking low 5',
#  'tso long crack spread say low 30 short vo good short',
#  'aap pain gain stay 500 mostly higher 580 go low 470',
#  'geoy trading 41 09 share worth 1 425 share dgi 28 84 x 1 425 41 09',
#  'china fix ing stdy',
#  'chk good info user user p 1470 thing rip imo',
#  'name like skypeople fruit juice sp going next aap wait see',
#  'wh consolidating high gap support immediately price',
#  'mt beav setting possible higher price',
#  'mgm caught ange user',
#  'new post could peter ynch stock md',
#  'fsc go ex dividend tomorrow paying monthly 0 0958 per share next payment jan 31st 10 60% yield',
#  'user 3dtradingtrader 3 1mio expend race offer depo',
#  'voxx user stock kudos friend',
#  'mcp performing expected many red flag raised one last month many could say told',
#  'swy wsj cerberus supervalu strike deal source may put bid swy',
#  'se shot ceco sm aci dmnd n gcy bbg ef tm eoc xco vccf pq axas pst p kcg mnta nav pac',
#  'hpq 16 50 call 04',
#  'aap daily pop vomit motion',
#  'mcp catch knife think survive define risk buy january 2015 eap option forget till',
#  'px ong 9 01 moved trailing stop 13 30 3 stop 9 01 7 78 6 55',
#  'aap see 1 3min candle row far',
#  'aap go red amazing many time pattern repeat',
#  'user u miss still going lower mcp',
#  'gdot making new higher high macd bullish cross obv trending upwards time fill gap',
#  'back full size position znga',
#  'fce triggered tues gapped wed today imo think take profit',
#  'goodbye faf acting weak never liked anyway next',
#  'likin msft neg dvrgnce hammer today goin quadruple bottom still longs w stop',
#  'wfc miss add',
#  'bac wait setup ooks like retest 10 66 sure',
#  'mcp lot red flag ceo abruptly fired without permanent replacement got attention',
#  'aap gonna bounce hard 516',
#  'g looking super strong',
#  'wait see w school 2013 user jmba airport location generally packed good news user',
#  'g want higher',
#  'aap watch c tell aap imo',
#  'bk added long',
#  'user long nfx 100 call 27 expire tomorrow 40 48% need greedy expiring tomorrow',
#  'jnp added long',
#  'cee 5 min retest',
#  'aap trimmed 1 2 short exposure 516 level',
#  'aap lower high lower low intraday big near term support',
#  'cult apple dying aap',
#  'zion look basing breakout could touch bottom triangle though',
#  'hpq ocket since noon',
#  'hpq ook volume nice 16 50 call',
#  'x took long exposure 25 95 26 area still bullish look stock rip n dip rhythm want dry powder 2 trade',
#  'user sweet money need another 1 8% scaling sell short csn',
#  'hpq man call option cheap',
#  'user user shot yhoo 0 one 19 go lololol',
#  'user lost 15% holding first opened recouped aap fb buying',
#  'te new short board utility sector',
#  'user tr8r x nice face check next hban green weekly triangle sell short',
#  'green weekly triangle hban sell short 6 69',
#  'user yea csn one whole portfolio scale always fix cost ending profit',
#  'bac 11 78 waiting pullback one today',
#  'aap moving 525 pivot today bullish tomorrow',
#  'aap getting attention showing strength might actually jump',
#  'e spy spx hold breakout e future',
#  'aap someone catch leak news 2 30',
#  'wfm getting much lift rally looking like possible bear flag adding short',
#  'ed weekly triangle hek net profit 4 539 00 10 84%',
#  'v interesting reversal today',
#  'bac 100% cash never listen siren say keep r trade overnight gapp never promise',
#  'hpq 17 50 much ask tomorrow',
#  'sdjpy breakout close isk rally equity trader front ski earnings e spy spx',
#  'market underperform day thanks ddd ssys position staying long 3d printing aap kept green upside come',
#  'green weekly triangle hek sell short 3 96',
#  'f solar market ise 22 percent 2013 deutsche bank predicts',
#  'nice user huge volume m breakout today',
#  'price action saying aap going die earnings multiple chance break 500',
#  'bn bish announce 15% increase holiday sale',
#  'c nice move 50 200 dma nice base structure daily weekly pattern',
#  'ocz ce 2013 vega nevada january 8th 11th progress',
#  'user user user game readyscoregoals company get canadiangrown',
#  'tell everyone user nice looking diverse list 52 week high jnj mmm g oc f wag de',
#  'alarm bell ring ddd investor ed flag highlighted detailed well researched article',
#  'aap marketing chief phil schiller resort cheaper iphone expand market share etes',
#  'squeeze squeeze slow grind higher continuing spy 147 45 e f 1471 wfc better deliver good tomorrow',
#  'hsa always come back',
#  'user hsa good day',
#  'yhoo cramer kiss death thanks bro get bac jds cramer nudge user kifmonster',
#  'mgm held long term resistance user mgm caught ange user',
#  'aon continuation good volume',
#  'nfx 28 20 28 40',
#  'zc 4 75 good volume',
#  'e spx spy star 4hour',
#  'doji like candle close today f may signify possible retracement 100% 61 8% fib level watching closely bull run',
#  'swhc continue accumulate mar 9 call pull back 8 10',
#  'isi continued volume go much higher 13 22 14 easy big green move',
#  'user tso fooled one day move esp large drop trend stop say still good',
#  'sm decent base ook poised break',
#  'user nfx let wkly 100 ca go vey green ed good hold',
#  'tso user attached show fib old resistance stopping upward move stay',
#  'cgi ove trucking co bought pullback',
#  'qcom best play samsung snapdragon anti aap play best tech play',
#  'qcom another view w blue sky',
#  'student debt trillion dollar bubble sm nni',
#  'cof approaching key resistance level 62 92 break could accelerate stock price',
#  'aon uptrend since july thursday break suggests continuation upmove',
#  'gdot w bullish macd cross along bullish si action matter time take',
#  'bac failed break uptrend continues',
#  'user financials xf already 4 6% ytd well fargo wfc might deliver moon today expectation',
#  'one small step send cable tv back 80 quality content exclusive nfx wait return ad',
#  'ong setup sm',
#  'user ddd 3d system win cnet best ce award cubex 3d printer',
#  'compq spx aap fb bac gd sv 5 characteristic successful trader',
#  'nkd sina two breakout stock watch list today buy high sell higher',
#  'msft take 26 29 gap fill jan 2012 26',
#  'm morgan stanley hit 1st bull signal target called dec 11',
#  'jcp cash flow distress sound good b downgrade sell',
#  'market wrap video addition watch ist including aeg di ipx ng onty qih st xxia',
#  'goog far good premarket average help could get 745 today',
#  'hpq think new mutual fund money going',
#  'x adding little',
#  'dk moving darvas box keep eye volume',
#  'gf open new position 35 52 new uptrend starting',
#  'bac effect wfc shod half hour moderately bullish',
#  'user ng long setup',
#  'trend outsourcing workforce extremely strong especially medical industry asgn lot room grow drogen',
#  'aap climb 525ish took small step backward wedge forming breakout imminent',
#  'hate reducing ddd position today getting big portfolio still bullish',
#  'aap took short exposure 2 3',
#  'would healthy desirable eventually put little handle shakeout climb present 58 90 pivot stdy',
#  'ed weekly triangle mh net profit 4 895 75 7 22%',
#  'time put goog warming lamp get heat languishing',
#  'green weekly triangle mh sell short 4 06',
#  'goog average trading lagging actually near low want see strong support 736 737',
#  'oc osing mkt share jds looking much lower price miss earnings',
#  'wfc think go green point today',
#  'user 3dtradingtrader go 6 60 sell depo',
#  'much topping action shorting key 8 90 shorting cat 95 stop 95 6 ike trade ot',
#  'mdso ong 27 51 trailing stop 37 00 7 prior stop 31 30 30 17 29 41 27 86 27 51 25 15 22 79',
#  'talking low priuced stock flying fce buy tuesday 30% gain way overbought',
#  'go 520 level aap',
#  'wpi whoopie stock nickname',
#  'nfx developing hge cup handle pivot 120',
#  'dnb call volume spike ahead earnings',
#  'anyone noticed hge volume today thing push 6 today might runner next week',
#  'mcp crater management tell u biz suck sort red flag people call bullish bottom delusionnal youondrugs',
#  'user iv day today take look apo 20 green day row since dec 13th rip tear',
#  'st watch list lien bit volume 51% full day average',
#  'apo 20 green day row far new high yet today',
#  'looking sustained upward momentum next friday option expire much interest holding aap',
#  'bac hate analyst scrap beautiful day',
#  'big setup early next week gnc probably run earnings market expects huge number eports feb 11 long',
#  'bac least resilient stock',
#  'cat holding 95 level beautifully today cup handle september january good market beak ot',
#  'gd trying break line finding support 200 sma ikely need gd hold 158 5',
#  'f 9 8 possibility market close much power hood',
#  'green weekly triangle ktos pdating',
#  'de approaching next level short back lower 61 8% fib old',
#  'f evel ii easing bit still allowing possibility late day run',
#  'awk en fuego part 2',
#  'user welcome tk club',
#  'gtat healthy pullback low volume nice run heavy volume positive macd divergence ong',
#  'tab user alexcampbello street see hence lower go',
#  'sold 3 4 0 27 2 94% keeping 1 4 position overnight',
#  'aap get pricing wanted added short close',
#  'market looking strong think financials catapult spx towards 1500 next week g bac',
#  'breakout',
#  'ht bearish',
#  'green weekly triangle dn pdating',
#  'demand breast implant time high good bad economy agn old wallstrip',
#  'offhand includes growth en spf mho itb ad ttm htz dom wk emn po sca wo fet bcei fxi hdb eve',
#  'wk 2 perf 13 stock 13 ddd dnkn ft invn ko nkd mov ntsp ax scco sca ssys v',
#  'nkd stormed back week 2 4 29% gain dog week 1 13for2013',
#  'cstr found support 26 ema nder 50 sma tho look short 26 ema add cloud break',
#  'pnra missed one yest short side short 50 sma',
#  'nkd following fb lead un 122 124 resistance user',
#  'although sound random aa earnings like week spx 0 62% next mo',
#  'short setup signal fire like 50sma reject weekly monthly time frame look like weakening',
#  'imm didnt come xmas bb10 take next xmas take share aap smart well timed',
#  'user shadowtrade1134 think fair analogy vhs beat beta le expensive aap',
#  'bear flag',
#  'pcn bull flag pennant',
#  'dndn nice vol expansion friday may worth watching buck',
#  'used border called showrooming hope work tgt nature retail changing',
#  'aap trend emains giving another sell signal',
#  'user sv super cheap stock appears getting ready fill gap current price nice name 2',
#  'user jmixer ino since jan 7 green weekly closed long 0 67 broker share borrow',
#  'user jmixer wait 0 57 charge weapon ino',
#  'ddd nice st pennant pattern ook breakout',
#  'iwd short 15 13 50',
#  'aap korea hot stock g display fall talk apple order cut',
#  'sigh aap continue keep qqq love see aap rebound negative news',
#  'aap imm apple reduces component order iphone 5 weak demand wsj say party ove',
#  'aap love',
#  'song aap bull',
#  'today could day aap break 500 rest market care change divorce qqq spy',
#  'aap thing ask today day buy feb 480 put',
#  'aap 25% short covered blow system would route nyseaca 0700 est offerd 499',
#  'aap 1 2 short covered',
#  'c play lower',
#  'well done short aapl friday gutsy got news needed',
#  'aap 500 great long term buy ignore noise',
#  'thank amzn pricing fire 199 nov 2011 et phone 13 wireless service 14 customer win',
#  'jnp acting well added back',
#  'aap bearish news bottom start new downleg',
#  'amzn momentum better buy aap goog close 270 might push 300 quickly',
#  'green monthly triangle chtp net profit 11 664 75 115 73%',
#  'pcn wait close 662 663 get involved name watch vome confirm uptrend continuation',
#  'aap sending reminder nok',
#  'cmg still good low risk reward short descending trend line core short bear call',
#  'coh close 60 extremely bullish watch',
#  'hpq heading back 20 imo fund oading',
#  'bac swing trade 8% protecting profit',
#  'remain convinced either apple stock aap another five year sold already middle ground',
#  'long aap break even eaiest sell 2014 dividend hike happens pe 9 right fy14 eps 56',
#  'csco c mon 21',
#  'aapl symmetrical triangle 5 min looking topside breakout',
#  'aap drop 25% since sep b c concern maybe 10% bump android phone sale mathfail oversell',
#  'aapl long per earlier tweet topside breakout st',
#  'aap appears dragging qqq spy stockaction',
#  'amzn snta ana ripping today even x setting new time high',
#  'fom breaking friday high strong continuation higher likely next resistance 5 37',
#  'vvs ong set',
#  'ook long de fixing miraculously hpq done de qqq xk',
#  'aap going interesting see pop squeeze jan 23rd see positive report',
#  'week later stock trending bullish 5 shale play 2013 apc he cop mo d b',
#  'user rare earth business fundamental terrible right mcp sort issue top compelling',
#  'user xraystocktrader great dividend pay continued upside eager see next acquisition cvx',
#  'user krisanti mentioned aap sent reminder nok',
#  'drug back lance gone user arge cap health well pfe jnj hit new 52 week high morning',
#  'marc benioff swagger income statement cm',
#  'green weekly triangle sho pdating',
#  'user anf triggering 48 70 buy price nice 15 min candle need build intra day momentum',
#  'hbi watch list briefly went line puled back volume ok 57% full day average',
#  'xxia 5 min found helpful watch 9 period ema pink using gap rule protect profit',
#  'aap fill upside gap within hr take eternity close downside gap environment clearly bearish',
#  'nice de',
#  'gw higher volume way news pump stock sound bullish',
#  'student nobiano made 14% roi bt trade great sir',
#  'user say might double money closed end fund gsvc year twitter pull good ipo',
#  'bac fib level',
#  'f buy 11 imo price target feb option',
#  'triple bottom rare third time aap traded near 500 last 2 month still many aap fanboys aap',
#  'hedgestreettrading son',
#  'hpq 17 50 call happy',
#  'hpq trading multiple oad freaking boat imo',
#  'awesomeness monday link swapping risk around financial blogosphere via user aap jo ga',
#  'going private new going public de',
#  'user t3ive look strong breakout play',
#  'csco msh msh msh 21 00 c mon mon',
#  'etail drill raise question xy xt th spx spy gps',
#  'f coiling hard right',
#  'k ong 53 69 trailing stop 52 16 2 prior stop 51 25 51 05',
#  'si vfc alcanza los 153 98 reconfirmaci n de la tendencia que lleva la sesi n provechando el rally alcista de final de sesi n',
#  'de 5x vol many people gonna lose butt buyout',
#  'think way many people bought dip 500 know aapl 420 plan equal mess',
#  'jeff bezos wonderful day usual thin bastard amzn',
#  'csco oo 21',
#  'aap let see say goodbye 500 today',
#  'totally helped beat revenue yoga bore western world bore well doritos',
#  'take aap index holding everyone back slacker',
#  'green weekly triangle sonc sell short 10 96',
#  'user de 14 75 would fill huge gap 5 22 12 lol good luck',
#  'ssys website investor relation page us morningstar stats quote mkt cap mon statistic wrong r share way',
#  'share fom drying accumulation continues daily technical indicator bullish',
#  'abc 123 clearing nice base drug pjp spx spy',
#  'user error morn data updated share outstanding equal 41 million 21million mkt cap 3 4 bil 1 8 bil',
#  'user stumbled upon data discrepency ssys mon yhoo ssys website say 21m share really 41m share',
#  'snts getting put open eally pleased decision came hour allows much better entry position',
#  'sfy would start trade second line starting 33 30',
#  'typical set 26 11',
#  'inap 717 riding 10ma extended based bolly deviation1 10ma right room upper bolly',
#  'aap need hold 500 could see lower price earnings within couple wks',
#  'hpq oad every dip everyone want',
#  'user aap hit 491 50 hedge fund margin leverage highest level since 2004 question many hedge fund blew today',
#  'aapl 490p 8 50 47% 5k',
#  'gnc perking despite general market weakness one better risk reward long setup long',
#  'user pi nice early action watch',
#  'po perking strong specialty chemical stock',
#  'jpm want go higher xf spy',
#  'de outside bbands believe pull bit',
#  'bk want buy lower hourly showing improvement added long',
#  'aap took 1 2 remaining short',
#  'tol finding support top cloud',
#  'zcs broke last week held well pulling back low volume keep eye possible breakout 83',
#  'csn sell short 9 38 scaling',
#  'new blog post momentum monday aap dip buyer missing market mojo',
#  'ampe sell short 4 48 scaling',
#  'sure everyone short aap make money everyone going jump market crash debt ceiling perfect',
#  'great move guggenheim hiring ex interim ceo yhoo',
#  'amzn pretty strong intraday support 269 5 still support break',
#  'apkt back 24 get interesting',
#  'aap earnings',
#  'look int clearing time high 10th time charm',
#  'user erased opening drive still 4 plenty room let consolidate',
#  'goog nice fast move low',
#  'mkt fat aap 2 5% cratering thru huge psychological level tell tape strong spy dontbeshort',
#  'amzn remember holding 269 5 important break continuation watch long add break yesterday high',
#  'user heo beautiful flag forming 7 10 eventually',
#  'depo sell short 6 43 scaling next level 6 27',
#  'aap study easons apple failed going stdy',
#  'user nvda growing cash cow 20 p eoy 2013 2014 xk amd stx qcom intc technology',
#  'path see real company new drug approval value lost shorters manipulation',
#  'thc watch list set well yesterday today line volume 46% ave full day',
#  'aj watch list triggered cent yesterday continues today volume 41%',
#  'odp breaking resistance',
#  'aapl 484 going level aapl trade today daytrade long side first quarter buy',
#  'reason try get cute try aapl long stick trend rev hold 489 500',
#  'confirming nicely today seeing double bottom daily pushing 20 day moving average 9 53 good action',
#  'tab mikel h williams helped acquisition viasystems group dennis f strigl use coo verizon com ceo verizon wirless',
#  'flipping aap trade 6 point never got meaty trade still obviusly long chipping away',
#  'user aap world apple expect order component 65 million iphone 5 handset seasonally soft march quarter',
#  'swhc obama biden speak tomorrow gun control legislation',
#  'user lot want cover 3 88 complete 25 35k share ampe',
#  'cmg exciting stock lately however upward trend still tact consistently pushing 20 day average 297 00 key',
#  'eading stock eading stock market esiient day indication ally continue e f gnc nsm eve ddd sti nf',
#  'apo accumulated bounce critical support 50 day 20 00 tell likely continues higher',
#  'aap broke downward triangle coming massive head shoulder thing toast',
#  'aap number one problem earnings expectation way high smart money know',
#  'chk squeezie',
#  'vvs breaking flag setup macd cross ong',
#  'chk 15 min kelt bbands fired earlier lunch 1 2 17 50 100%',
#  'hpq come back de get bought hpq ocket',
#  'aap dumping close still see going sub 400 maybe earnings report wk two gy town',
#  'aap many people believe apple commenting stock decline b 4 ec called quiet period reason',
#  'dgi ddd acting strong ending hod decent volume end',
#  'ed monthly triangle cytx net profit 9 845 00 11 01%',
#  'green weekly triangle cytx sell short 3 02',
#  'wmb might fill gap reverse',
#  'f inside day add long break stop life little 30 area',
#  'aap probability rising test 2003 trendline st mean reversion pt 350',
#  'wfm look like bear flag short respect flag exit close',
#  'bcei 31 30',
#  'dcth back 1 52 1 55 like volatility low priced one',
#  'amzn still uptrend motion buy dip',
#  'nfx next resistance level 110',
#  'pcn long setup',
#  'aap break 5 year support line apple would depend itv take 52wk h',
#  'vg consolidating inside large ascending triangle w tp around 3 breakout watch 2 55',
#  'aap trading close point figure trend line support next target 470 trend support',
#  'bac yep b good day financial soon volume 9 30am ise p',
#  'cie cox cmg getting smacked open',
#  'ssys postpone q4 release feb approx march 4th',
#  'check list top performer since aap peak user dog like f de 80% nfx please',
#  'new post positive earnings cost containment continue propel m',
#  'goog amzn showing early weakness',
#  'amzn take yesterday low ong better careful',
#  'aap revers early gain qqq really big problem',
#  'oabc ong 16 55 trailing stop 22 80 8 prior stop 21 16 20 18 19 00 18 70 16 74 15 90 15 25',
#  'twc way potential breakout 99 channel tgt 100 102 wht u think user',
#  'nvda breaking 30 min trend',
#  'aap ong position apple reaching 503 38 maximum day stop loss 500 4',
#  'ceg high fast one well due pull back 100 00 key',
#  'aap apple reach 504 44 change stop os put 501 60 also chance go long',
#  'ann 200 period hammering ooks good 4 month pattern',
#  'bac p p step step esistance 11 65 67',
#  'dip buyer alive well everywhere user dip buyer alive well jpm',
#  'nvt 1 73 v oc 1 73 went w oc vol difference today roll end wk oc opinion could wrong',
#  'green weekly triangle gpn pdating',
#  'bac 11 75 12 00 today',
#  'cndo 5 78 ooking 7% one',
#  'nvt unusual increase socialvolume',
#  'ong cf',
#  'fio ioscale announced today open compute summit hyperscale spinning disk replacement another game changer',
#  'user twitter follower bullish bearish aap want know bullish cautious',
#  'nvda ihs daily oversold',
#  'deck proving bullish confirming bouncing 20 day increased volume',
#  'aap still long bull charge today',
#  'user nfx ising wedge normally bearish close 94 confirms nice one',
#  'csn catch bottom bought weird dip hope manipulation mean good thing come',
#  'g solid move higher new high today strong volume',
#  'nyny moving right along',
#  'student stephanie n said hoy gacamoe 30 second made 24% oi nfx user tradesmart',
#  'ed weekly triangle csn ong 6 8815',
#  'aap 100 week support',
#  'wcg onged today swing',
#  'aap one reliable pattern come across surprising intraday pattern study',
#  'yhoo volume big closing 20 today give enough fire make new 52 week high later week',
#  'hpq open 18 tomorrow',
#  'user hey great call hpq think fund buying',
#  'bac imho think gap e',
#  'hpq going nail mofo hpq going spotlight tonight ooking eal gapper tomorrow',
#  'swhc bet pm mid high 9',
#  'aap long call atio back spread 510 505',
#  'user hpq double top taken close watch learn',
#  'g swhc market may figuring legislation gun pas much shooting time load',
#  'bac ike told 11 75 aftermrkt good setp tmorrow',
#  'goog daily chaos event looking good green line moving white like dec9 move',
#  'green weekly triangle cytx pdating',
#  'hpq autonomy looked total loss could sell wish hpq strong ptrend oad',
#  'apple falling aap',
#  'hpq many upgrade tomorrow assuming autonomy worth something',
#  'hpq nice close imo',
#  'fod cover 3 93 net profit 1 571 00 ugly triangle fod',
#  'csn target remains 9 data news',
#  'dva really nice break dt line volume today',
#  'ssys exuberance stock generating 2million operational cash flow 9mos trading 3 4 billion u could say top',
#  'big win broker new mini option bring big change trader via user spy aap goog amzn gd',
#  'wmt buy signal easy math baby good discount',
#  'thought call early screamed fashion makeover wow look good',
#  'jpm whale trader',
#  'watching ba',
#  'cmg keep level mind bounce 284 288 followed leg 238 bounce 254 leg 212 202',
#  'v 11 35',
#  'disney new infinity game going huge take dis atvi',
#  'ba come back haunt year say eap sow',
#  'pgx hype spot 6 88 90 b 6 91 resist daily til 200sma 7 33ish 50sma sliding',
#  'dn first hint trendline break upside',
#  'aap going confirmed theory selling came inside info last 45 day cat bag sucker left bullish',
#  'aap another downgrade broken',
#  'bac bank america earnings stronger expected',
#  'goog amzn call watch list day trade taking break aap',
#  'aig going premarket somebody know something know',
#  'bac since earnings seem impact price break 12 card good longterm hold',
#  'looking good 22 50 call',
#  'user goog put option 8 year high interesting',
#  'trade setup akam',
#  'trade setup aa',
#  'trade setup cf',
#  'ow pt hit resistance',
#  'sanm watch list volume 9% ave full day slightly line',
#  'hpq explode today 18 coming imo',
#  'ceg confirming expectation 98 50 ikely crack',
#  'garden wall browser amzn aap',
#  'american apparel app present 11 05',
#  'csn correction thermodox nanosoccer ball anti vascular well anti neoplastic',
#  'pi daily thx head user',
#  'gme 23 40 look good go',
#  'wow saw price next week e 1 22 goog 720c 20',
#  'raising stop ow right today low around 35 90',
#  'wn ong 19 79 trailing stop 26 64 7 prior stop 24 39 23 76 20 42 19 79 18 09 17 13 16 39',
#  'demark coming back prop aap yesterday classic dead cat bounce value stock need go lower find size buyer',
#  'ng liked stewie mentioned 20ma first pullbk2 would b good 2nd entry',
#  'ana',
#  'bookmark arry page moonshots matter must option market exist goog',
#  'swy drinking safeway store brand columbian whole bean coffee sbx cup',
#  'back bk long nice reaction earnings making runaway measuring type gap',
#  'ko kept wishing first cousin looking good',
#  'tivo holding well 50 11 60 morning believe long setup',
#  'smb adar weak today fast adtn cam',
#  'ssys add 100 million market cap today',
#  'user ana look like coil setting',
#  'hott fngn pim fnf moonshots',
#  'wmt h struggling 200dma well mm target 10 handle gap fil',
#  'ipx biotech watchlist vol 42% full day ave moving toward gap 200 day need vol',
#  'swy wow number bear week scaled little today',
#  'aap 900 lot offered eg jan 500 put 1 71 28 delta put could push stock create support',
#  'wcg everybody looking something buy basement trade w fundamental',
#  'amzn trying break higher',
#  'user intc yep follow money look like something good coming pipeline',
#  'ba shot 130 75 25',
#  'green weekly monthly triangle isi sell short 14 14',
#  'g exploded last hour green bar since 1',
#  'bac turn run spy watch eod eversal',
#  'faf look good pivot range 24 87 26 11 volume 76% today see close get day high 25 60',
#  'user really buy card christmas',
#  'c big pop bac follow',
#  'wpi inside day crack downside already short add',
#  'znga lot support smas bot share 2 54 falling low volume',
#  'gevo watch break 2 08 test recent high 2 43',
#  'ssys voyant advisor negative report see high risk earnings earnings risk 9 scale 1 to10',
#  'ssys nov 13 report piper jaffray put new price target report 76 dougherty december report put tgt 67',
#  'user bac consolidation progress yep consolidating 10 go emotion anonymous take hard',
#  'zion cup handle pattern stock would confirm pattern breaking 22 8',
#  'gevo broke bull flag pattern upside today move accompanied high volume',
#  'added holding aap bid fb ah also holding ddd 25% cash',
#  'bac hawken price target 11 50 estimating company earn 95 cent 2013',
#  'nice one user marketshare margin aap dilemma',
#  'dpz nice intraday upward reversal adding bull flag keep watch move 46',
#  'tex another nice bull flag watch macd signal next breakout',
#  'wh also strong day today look ready next leg',
#  'gmc keeping nice consolidation make big move soon macd si turning',
#  'aj really strong caution overbought si declining macd',
#  'cen nice gap support look ready head higher',
#  'wynn nice bullish consolidation could pop soon',
#  'v similar pattern wynn bull flag building keep watch',
#  'clear downtrend sign relief',
#  'also healthy fell back dt line breaking si weak macd turning',
#  'nfx hammer breakout back test watch tomorrow bounce',
#  'intc anyone thought late algo trading option oi affect stock price tomorrow guess 20 50 21 50 close',
#  'need body part ihi syk mdt zmh user nice call bsx',
#  'aap qih cheapest transparent china play apple avoid soes management decision based guanxi party interest',
#  'user a36tran user said many time aap big money shifting towards stock 11 12 13 14',
#  'ow breaking new 52 week high',
#  'g quiet lately good get pop',
#  '19 60',
#  'intel earnings capex mobile matter eps mean pc biz decline news intc hpq aap de amh',
#  'new blog post watchlist 01 17 f kbh gpx ssq sbx csod hd wt ocn ebay tex chk itg',
#  'bac user hope consolidation level drop stop 11 support nxt 4 5 day come back to12 imho',
#  'hot osers fns tsx intc amn jds',
#  'geo nice pop morning moving stop breakeven',
#  'long aci 7 39',
#  'cee clear chasing entered monday ong',
#  'adbe continues weaken following market short break 37 60 user',
#  'v far found support ceiling old channel look good hold',
#  'user adbe continues weaken following market short break 37 60 user',
#  'shw ong 131 42 trailing stop 140 12 4 stop 138 36 125 06 122 79 118 70',
#  'bac fully engaged within secondary reaction 12 43 high 1 07 point 10 80 50 target zone',
#  'bac still see getting back 10 50 possibly lower overall market pull back next month',
#  'user g two week away earning ready rocket within two day',
#  'aap 497 area likely fail',
#  'wh gap filled',
#  'monday aap said 500 pin still confident close 500 pin take look crazy oi spike',
#  'stt strong bounce today continues make new high sharing one day nice run',
#  'csn another sa article ongs',
#  'aap percolating perhaps push 500 soon',
#  'swy corn run bear getting cob swy',
#  'aap wall st hated stock currently careful short anything short disaster viewed positively bit risky long mainevent',
#  'fio insightful analysis fusion io avoiding commoditization via user',
#  'mcp sorry kid nissan siemens getting mining business fun buying whatever somebody trying unload',
#  'csn know crazy thought go green eod',
#  'schw break flag',
#  'g ask pummeled manager cannot miss afraid missing train',
#  'wh nice rounded reversal pattern intraday since gap fill',
#  'e f spike bottom eading stock comatose still leading wake p ocn sbgi nsm five gnc make say hmmmm',
#  'amat reached high overbought condition wait pullback enter long',
#  'aci option trader buy 20k feb 7p hard offer v oi 1 400 earnings feb 5th bmo could hedge long stk',
#  'zion stalking cup handle potential breakout w anemic volume handle breakout candidate',
#  'vfc short one bull need hold support break could significant',
#  'bac anyone think might slush fall 11 today',
#  'big boy stock ge starting build constructive right side current 14 week cup base',
#  'aap possibility exists',
#  'egarding going ks wmt tgt tjx os see many copycat clothing item reminds cox 70 sub 1',
#  'dnkn seeing lot talk one put another nice day steady uptrend',
#  'green weekly triangle essx pdating',
#  'applesoft different time aap',
#  'green weekly triangle hban pdating',
#  'ltra base tek ltratech step stepper',
#  'dec ge long ia 20 00 stock plague world love 22 tell headed knew heading',
#  'eversal confirmed closing nicely 20 day 9 47 also confirming today imm chk others like',
#  'wk 3 13for2013 portfolio ddd dnkn ft invn ko nkd mov ntsp ax scco sca ssys v',
#  'invn report next week 3rd 13 5% gain year 13for2013 watch cup w handle wkly',
#  ...]

# %%
input_data['cleaned'] = cleaned_buffer
input_data.head()
# Out:
#                                                 text  sentiment  \
# 0  user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 1  user I'd be afraid to short AMZN - they are lo...          1
# 2                                  MNTA Over 12.00            1
# 3                                   OI  Over 21.37            1
# 4                                  PGNX  Over 3.04            1
#
#                                              cleaned
# 0  user aap movie 55% return fea geed indicator 1...
# 1  user afraid short amzn looking like near monop...
# 2                                         mnta 12 00
# 3                                           oi 21 37
# 4                                          pgnx 3 04

# %%
#split into training and test data sets
xtrain, xtest, ytrain, ytest = train_test_split( input_data['cleaned'], input_data['sentiment'],
                                                               test_size=.4, random_state=10)
xtrain
# Out:
# 582                  msft take 26 29 gap fill jan 2012 26
# 3524    need liste little devil shoulder often 1000 mt...
# 134     aap top april aston kutcher star job kinda lik...
# 2621    goog market leader heading next century mark 8...
# 997     eversal confirmed closing nicely 20 day 9 47 a...
#                               ...
# 1180                         aap da 2 % gef llt mir nicht
# 3441    new blog post followup yesterday watchlist ots...
# 1344    gtat holding 50sma ooks like stock could try t...
# 4623                  gw corning set emerge 18 month base
# 1289    user h broke support today may drop channel to...
# Name: cleaned, Length: 3474, dtype: object

# %%
tfidf = TfidfVectorizer(ngram_range=(1,3))
xtrain_tf = tfidf.fit_transform(xtrain)
print("nsamples: %d, nfeatures: %d" % xtrain_tf.shape)

xtest_tf = tfidf.transform(xtest)
print("nsamples: %d, nfeatures: %d" % xtest_tf.shape)
# Out:
# nsamples: 3474, nfeatures: 57630
# nsamples: 2316, nfeatures: 57630

# %%
print(xtest_tf)
# Out:
#   (0, 42903)	0.4415425405754121
#   (0, 42881)	0.2667092374907307
#   (0, 8352)	0.42038109765368015
#   (0, 8348)	0.2839049348989414
#   (0, 8306)	0.32686820349996853
#   (0, 8216)	0.3691910893434322
#   (0, 3523)	0.21834102665199873
#   (0, 3395)	0.33998443920835736
#   (0, 663)	0.2649093853408777
#   (1, 45368)	0.510097570366633
#   (1, 25696)	0.510097570366633
#   (1, 25695)	0.510097570366633
#   (1, 14855)	0.3210467802934407
#   (1, 12960)	0.3410723837858898
#   (2, 31576)	0.822655797157474
#   (2, 31525)	0.4690720683613014
#   (2, 5270)	0.32126131744492964
#   (3, 53636)	0.278052157054106
#   (3, 25370)	0.6107922209596574
#   (3, 19603)	0.7019442429341386
#   (3, 5270)	0.23852492654719917
#   (4, 54614)	0.14534575715856426
#   (4, 31856)	0.20963214640606526
#   (4, 31775)	0.15848079748007413
#   (4, 30806)	0.30651812917821897
#   :	:
#   (2313, 47638)	0.15337363921567604
#   (2313, 44688)	0.26061093268006646
#   (2313, 44557)	0.13860070835600663
#   (2313, 43182)	0.19655511431514644
#   (2313, 41719)	0.19292688597246394
#   (2313, 35112)	0.19655511431514644
#   (2313, 24080)	0.23925899322509311
#   (2313, 18744)	0.26061093268006646
#   (2313, 18383)	0.26061093268006646
#   (2313, 18378)	0.23925899322509311
#   (2313, 17990)	0.23925899322509311
#   (2313, 17985)	0.20809729766527582
#   (2314, 56110)	0.28940494490603846
#   (2314, 52559)	0.2683071593537144
#   (2314, 52539)	0.2167287372256918
#   (2314, 44204)	0.31537191710933615
#   (2314, 31120)	0.21818108609672981
#   (2314, 27620)	0.3450664731219909
#   (2314, 26645)	0.3450664731219909
#   (2314, 26644)	0.3450664731219909
#   (2314, 12475)	0.31537191710933615
#   (2314, 11756)	0.36243667486495795
#   (2314, 11716)	0.2493789608718615
#   (2315, 32268)	0.5591857976528889
#   (2315, 14784)	0.8290423654453989

# %%
#bayes classification
nb_classify = MultinomialNB()
nb_classify.fit(xtrain_tf, ytrain)
# Out:
# MultinomialNB()

# %%
predictions = nb_classify.predict(xtest_tf)

# %%
results = metrics.classification_report(ytest, predictions)
print(results) #naive bays
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.85      0.19      0.31       826
#            1       0.69      0.98      0.81      1490
#
#     accuracy                           0.70      2316
#    macro avg       0.77      0.59      0.56      2316
# weighted avg       0.74      0.70      0.63      2316

# %%
print(metrics.confusion_matrix(ytest, predictions))
# Out:
# [[ 158  668]
#  [  28 1462]]

# %%
#Now do with random forest

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
randforest = RandomForestClassifier()
scores = cross_val_score(randforest, xtrain_tf, ytrain.values.ravel(), cv=5)
print(scores)
# Out:
# [0.75971223 0.74100719 0.74964029 0.73381295 0.71613833]

# %%
#this is hyperparameter tuning, but with very few params
params = { 'n_estimators' : [5, 10, 25, 50, 100], 'max_depth' : [2, 5, 10, 20, None]}

grid_search = GridSearchCV (randforest, params)
grid_search.fit(xtrain_tf, ytrain.values.ravel())
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 5, 10, 20, None],
#                          'n_estimators': [5, 10, 25, 50, 100]})

# %%
all_means = grid_search.cv_results_['mean_test_score']
all_std_dev = grid_search.cv_results_['std_test_score']
all_params = grid_search.cv_results_['params']
#print(all_params[1]['max_depth'])
for x in range(0, len(all_means)):
    print(all_params[x], "\t", all_means[x], "\t", all_std_dev[x])
# Out:
# {'max_depth': 2, 'n_estimators': 5} 	 0.632124064437211 	 0.0008149416010404049
# {'max_depth': 2, 'n_estimators': 10} 	 0.6324126635291191 	 0.0009721290872219675
# {'max_depth': 2, 'n_estimators': 25} 	 0.6315485248688658 	 0.00021230278025421434
# {'max_depth': 2, 'n_estimators': 50} 	 0.6315485248688658 	 0.00021230278025421434
# {'max_depth': 2, 'n_estimators': 100} 	 0.6315485248688658 	 0.00021230278025421434
# {'max_depth': 5, 'n_estimators': 5} 	 0.6352895320631102 	 0.004131627117809366
# {'max_depth': 5, 'n_estimators': 10} 	 0.6335629133580744 	 0.0022605693693205585
# {'max_depth': 5, 'n_estimators': 25} 	 0.6318362946530384 	 0.0006613717490850005
# {'max_depth': 5, 'n_estimators': 50} 	 0.6318362946530384 	 0.0006613717490850005
# {'max_depth': 5, 'n_estimators': 100} 	 0.6315485248688658 	 0.00021230278025421434
# {'max_depth': 10, 'n_estimators': 5} 	 0.6358663155930587 	 0.002416779609735369
# {'max_depth': 10, 'n_estimators': 10} 	 0.6387473306657269 	 0.005300879968914325
# {'max_depth': 10, 'n_estimators': 25} 	 0.6355789604627538 	 0.0024105774834718876
# {'max_depth': 10, 'n_estimators': 50} 	 0.632124064437211 	 0.0008149416010404049
# {'max_depth': 10, 'n_estimators': 100} 	 0.6332755582277694 	 0.001446738218721974
# {'max_depth': 20, 'n_estimators': 5} 	 0.6485335765969358 	 0.0054596979545548235
# {'max_depth': 20, 'n_estimators': 10} 	 0.6548616092716604 	 0.010534622717172249
# {'max_depth': 20, 'n_estimators': 25} 	 0.6511210167312835 	 0.007824287354749103
# {'max_depth': 20, 'n_estimators': 50} 	 0.6453639624323596 	 0.003398698379911719
# {'max_depth': 20, 'n_estimators': 100} 	 0.6465175294922563 	 0.002245140829790722
# {'max_depth': None, 'n_estimators': 5} 	 0.7104152758484854 	 0.014843434737752983
# {'max_depth': None, 'n_estimators': 10} 	 0.7334455663135199 	 0.017249677566576936
# {'max_depth': None, 'n_estimators': 25} 	 0.7423672589306076 	 0.016780741918414204
# {'max_depth': None, 'n_estimators': 50} 	 0.7478361287914913 	 0.014290561161073221
# {'max_depth': None, 'n_estimators': 100} 	 0.7412153504861816 	 0.012959415392618885

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
#doing this again but with arbitrarily picked, because why not?
forest1 = RandomForestClassifier(n_estimators=50, max_depth=5)
forest2 = RandomForestClassifier(n_estimators=25, max_depth=20)
forest3 = RandomForestClassifier(n_estimators=100, max_depth=None)

forest1.fit(xtrain_tf, ytrain.values.ravel())
forest2.fit(xtrain_tf, ytrain.values.ravel())
forest3.fit(xtrain_tf, ytrain.values.ravel())
# Out:
# RandomForestClassifier()

# %%
for x in [forest1, forest2, forest3]:
    predictions = x.predict(xtest_tf)
    results = metrics.classification_report(ytest, predictions)
    print(results)
    print("+++++++++++++++++++++++++++++++++++")
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       826
#            1       0.64      1.00      0.78      1490
#
#     accuracy                           0.64      2316
#    macro avg       0.32      0.50      0.39      2316
# weighted avg       0.41      0.64      0.50      2316
#
# +++++++++++++++++++++++++++++++++++
#               precision    recall  f1-score   support
#
#           -1       0.85      0.05      0.09       826
#            1       0.65      1.00      0.79      1490
#
#     accuracy                           0.66      2316
#    macro avg       0.75      0.52      0.44      2316
# weighted avg       0.72      0.66      0.54      2316
#
# +++++++++++++++++++++++++++++++++++
#               precision    recall  f1-score   support
#
#           -1       0.66      0.58      0.62       826
#            1       0.78      0.83      0.81      1490
#
#     accuracy                           0.74      2316
#    macro avg       0.72      0.71      0.71      2316
# weighted avg       0.74      0.74      0.74      2316
#
# +++++++++++++++++++++++++++++++++++
# C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#now with official hyperparameter tuning
#creating the grid
nestimators = [int(x) for x in np.linspace(start=5, stop=300, num = 5)]
max_features = ['auto', 'sqrt']

max_depth = [int(x) for x in np.linspace(10, 100, num=5)]
max_depth.append(None)

min_samples_split = [1, 2, 5, 10, 20, 25, 50, 100]
min_samples_leaf = [1,2,3,4]
bootstrap = [True, False]

grid = {'n_estimators': nestimators, 'max_features':max_features, 'max_depth':max_depth,
       'min_samples_split':min_samples_split, 'min_samples_leaf':min_samples_leaf, 'bootstrap':bootstrap}

# %%
#if you can avoid running this again, that'd be nice. Took at least 5 hours with iter=1000/cv=5
rf_regress = RandomForestRegressor()
rf_rand = RandomizedSearchCV(estimator=rf_regress, param_distributions=grid, n_iter=1000, 
                            cv=5, verbose=2, random_state=10,n_jobs=-1)
rf_rand.fit(xtrain_tf, ytrain)
# Out:
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 615 fits failed out of a total of 5000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 290 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     trees = Parallel(
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 187, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1315, in fit
#     super().fit(
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 250, in fit
#     raise ValueError(
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
# --------------------------------------------------------------------------------
# 325 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     trees = Parallel(
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1315, in fit
#     super().fit(
#   File "C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 250, in fit
#     raise ValueError(
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Patrick\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [ 1.52805570e-02             nan  2.24085394e-01  1.74351531e-01
#              nan  2.28296869e-01  2.19612703e-01  2.22101470e-01
#   1.18086961e-01  8.99180996e-02             nan  2.18468174e-01
#              nan  1.72230065e-01             nan  1.59065692e-01
#   2.22114078e-01  1.53468066e-01  1.83124632e-01  4.05596254e-02
#              nan  2.15037440e-01  2.24947402e-01  1.41820944e-01
#   1.17388671e-01  4.41361873e-02  1.53641002e-02  2.27953241e-01
#              nan             nan             nan  4.44339206e-02
#   1.84012792e-01  4.83795217e-02  2.47786524e-01  2.27546188e-01
#   1.13261479e-01 -3.24927348e-02  1.26387882e-01  2.18446837e-01
#   2.11516311e-01  1.95938662e-01 -7.01035695e-02  2.02531530e-01
#   2.04354729e-01  1.54691994e-01  1.98436872e-01  2.44396666e-01
#   2.21576280e-01  1.98731749e-01  2.35274674e-01 -4.01270815e-02
#   4.19927142e-02  1.08337040e-01  2.26674313e-01  6.60646406e-02
#   1.11641823e-01  2.42997113e-01  1.87978137e-01             nan
#   1.53188861e-01  4.53473908e-02  1.15835799e-01  1.60816232e-01
#   1.12135042e-01             nan  1.62248846e-01  1.70888551e-01
#   4.27605934e-02  2.17751561e-01  1.48909138e-01             nan
#   4.18348897e-02  1.19648814e-01  6.88111444e-02  1.53377171e-02
#   1.44123343e-01  1.98316050e-01  1.45074343e-01             nan
#   2.32224586e-01  2.10084676e-01  1.44281145e-01  2.47450211e-01
#   2.11587497e-01  1.69986131e-01  1.02575428e-01  2.22814110e-01
#   4.81773878e-02  1.30202765e-01  1.14877662e-01             nan
#   1.46296061e-01 -2.36228289e-02  1.81337590e-01  2.27354723e-01
#   3.02962806e-02  1.72814423e-01  1.69992785e-01  2.38831058e-01
#   8.11498303e-02  1.71445824e-01  1.96632439e-01  1.68301929e-01
#              nan  1.47031425e-01  2.36475951e-01  2.23648870e-01
#   4.63559992e-02  2.33344699e-01 -2.96927091e-02  1.08577404e-01
#   1.95750366e-01  9.09983620e-02  1.18698080e-01  1.09733519e-01
#   1.14143638e-01  7.61221818e-02  2.34797190e-01             nan
#   2.24606189e-01  1.70308400e-01  3.63165424e-02             nan
#   1.59434487e-01  2.25231458e-01  1.79335867e-01  6.13047685e-02
#   1.38001806e-01  7.17657922e-02  2.12332405e-01  2.24773645e-01
#   1.04935154e-01  2.29080945e-01  1.51282594e-01  1.45190613e-01
#  -2.50617818e-02  1.39486028e-01  2.40574966e-01  5.97445345e-02
#              nan -1.94633637e-02  1.45540057e-01  5.95000989e-02
#   2.37794475e-01  9.01225988e-02  2.41906349e-01  2.26650437e-01
#   1.13310471e-01  1.04122792e-01  1.15333064e-01  1.30528051e-01
#              nan  2.32888442e-01  9.53111452e-02  2.23289377e-01
#              nan  1.85763039e-01  2.12226698e-01             nan
#              nan  2.17901512e-01             nan  1.99040295e-01
#   1.01501779e-01  1.03802013e-01  2.10871908e-01  1.37670232e-01
#   5.63793964e-02  2.02315991e-01             nan             nan
#   2.32442247e-01  2.14366259e-01  1.84166106e-01  1.03920843e-01
#   2.98653369e-02  1.97912270e-01  4.75294923e-02  9.42368310e-02
#   1.53228491e-01  1.08025310e-01  1.23578173e-01  1.45357116e-01
#   2.20575489e-01  4.66096753e-02  2.30445933e-01  1.15422618e-01
#   1.34407933e-01  2.28774182e-01  4.16970683e-02  1.76268126e-01
#   1.30597285e-01  2.15346487e-01  4.41569473e-02  8.99708827e-02
#   2.17767176e-01 -8.86077361e-02  1.34793034e-01  1.65569532e-01
#   1.70562202e-01  3.76784844e-02  1.36029086e-01  2.30842126e-01
#   1.95844398e-01  1.04254994e-01  1.07242097e-01  4.58352475e-02
#   1.52630350e-01  2.39946636e-01  2.36091923e-01  1.40208702e-01
#   2.46239221e-01  1.14586889e-01  2.73894307e-01  2.38557651e-01
#              nan  4.28246356e-02             nan  2.27041996e-01
#   1.51275915e-01  3.23053388e-02  4.38428432e-02  1.39917762e-01
#   2.27126934e-01  6.06650035e-02  1.09049500e-01  4.45221039e-02
#   1.75024736e-01  1.72754546e-01  1.98120414e-01  1.95658930e-01
#   1.89706938e-02             nan  2.17765449e-01  1.40506296e-01
#   4.55837521e-02  1.13581924e-01  1.29294527e-01  1.64847768e-01
#   1.96839710e-02  9.59740455e-02             nan  9.19827647e-02
#   1.93600078e-01  1.21948628e-01  2.79754781e-01  8.96940194e-02
#   1.19125538e-02  9.65820916e-02  7.11835854e-02  4.83682959e-02
#   1.66651643e-01  1.62902809e-01  2.17522087e-01  2.19753115e-01
#   1.45807704e-01  1.87920806e-01  2.76791520e-01  1.03068410e-01
#   4.50763387e-02  1.29234307e-01  1.35633832e-01  1.11879962e-01
#              nan  3.91587573e-02  1.76612744e-01  1.70423304e-01
#   4.24412366e-02  2.23181964e-01  2.13493057e-01  8.86163093e-02
#   9.75822683e-02  1.62044121e-01  1.81254972e-01  2.38003801e-01
#   9.83941695e-02  4.50969825e-02  1.71828716e-01  1.96420508e-01
#   2.32228469e-01 -6.58174619e-02  1.84936946e-01  2.29544536e-01
#   1.44811324e-01             nan  1.58869652e-02  1.73530220e-01
#              nan  1.51552547e-01  2.45728849e-01  9.70203275e-02
#   1.85429465e-01  2.35157052e-01  2.22932784e-01  1.03939274e-01
#   2.32010093e-01  1.34617963e-01  6.42785438e-02  1.81581210e-01
#   2.35762181e-01  1.66359122e-01  1.42957020e-02  4.32995188e-02
#  -6.28892642e-02  1.11235193e-01  2.19710124e-01  2.13525013e-01
#              nan  1.45153852e-01  2.22906844e-01  2.33259134e-01
#   1.05500423e-01  1.15380902e-01  1.44791364e-01  1.72895344e-01
#              nan  1.45725765e-01  1.67565728e-01             nan
#   1.66810469e-01  1.55132329e-01  1.07695187e-01 -2.66361071e-02
#   8.93739482e-02             nan  2.21811434e-01             nan
#   2.38293206e-01  1.37966607e-01             nan  4.83404082e-02
#   1.63975521e-01  1.42586351e-01  1.04439165e-01  8.38975991e-02
#   1.68740850e-01  7.07716514e-02  1.98568536e-01  1.63700812e-01
#   1.42893007e-01  2.40114664e-02  4.03336188e-02  2.12665025e-01
#   2.39970660e-01  1.66943832e-01  4.45526286e-02  5.58360568e-02
#   2.42468003e-01  2.21665557e-01  1.03347467e-01  1.73946430e-01
#   2.70472093e-01  9.77572846e-02  1.88739590e-01  2.66757455e-02
#   1.95098386e-01  2.24461216e-01  1.74237834e-01  1.95551165e-01
#   1.05046937e-01  1.09243932e-01             nan  2.23094400e-01
#   2.36197036e-01  1.83752808e-02  2.45750420e-01  4.76823906e-02
#   1.43443464e-01  1.06529237e-01  4.98648396e-02  1.69236385e-01
#   4.39937095e-02  2.23034246e-01  9.78361792e-02  1.37198844e-01
#   2.24320706e-01  1.61524575e-01  4.06599561e-02             nan
#              nan  1.26961422e-01             nan  2.17068509e-01
#   2.73680262e-01  1.96886379e-01  1.08990074e-01             nan
#   4.64395801e-02  1.66391454e-01  3.57653931e-02  9.03529019e-02
#   2.25620073e-01  4.22193784e-02  2.26722709e-01  1.62081924e-01
#   1.50341881e-01  1.27164511e-01  5.33847051e-02             nan
#   2.31311278e-01  1.06674992e-01  1.63185692e-01  1.93296333e-01
#   2.24590988e-01  5.42731532e-02             nan  1.97317405e-01
#   2.78028304e-01  1.09473451e-01  8.08725874e-02  1.63301187e-02
#   4.18638043e-02             nan  1.90081324e-01  1.06201395e-01
#   1.17005955e-01  1.15039576e-01  1.70505073e-01  4.36313995e-02
#   6.94392231e-02  1.86009542e-01  2.35050014e-01  2.72868764e-01
#              nan             nan             nan  2.07345987e-01
#   2.37199831e-01  2.25972553e-01  2.47339216e-01  2.22194564e-01
#   1.05283153e-01  1.97722966e-01  2.01845437e-01  1.86298584e-01
#   5.96025854e-02             nan  1.72755384e-01  2.23132955e-01
#   1.20017776e-04  8.46872730e-02  1.44096820e-01  1.20232251e-01
#   1.42556402e-01  2.84486395e-02  9.01170038e-02  2.11992628e-01
#  -3.25815534e-02  7.31126889e-02  1.37824129e-01  2.10670320e-01
#   2.26210794e-01  4.77625700e-02  2.38827220e-01  2.44389393e-01
#   8.50642336e-02  2.81664579e-01  2.15698814e-01  1.95294053e-01
#   3.47849303e-02  2.34613394e-01  1.49197451e-01  4.09092611e-02
#   1.99555928e-01  1.55596296e-01             nan  4.50691371e-02
#   1.86446380e-01  2.22586073e-01  2.36473081e-01  2.51246960e-01
#   7.43743529e-02  2.25351192e-01  1.05262714e-01  1.12408909e-01
#              nan             nan -7.58065294e-02  1.04450042e-01
#   2.25346283e-01  1.09163641e-01  2.29963500e-01  1.04458815e-01
#   1.64643637e-01  2.23139529e-01  1.67477824e-01  1.21981750e-01
#   2.23409392e-01  1.24437119e-01  2.74390376e-02  2.11327201e-01
#   2.77898287e-01  4.14726381e-02  1.66268770e-01 -5.02891585e-02
#   1.57745716e-01             nan  1.94627488e-01  2.20738459e-01
#   4.60525187e-02  1.07056748e-01  9.53395219e-02             nan
#   1.64981107e-01  1.88666007e-01  2.07003804e-02  2.40404069e-01
#   1.90417426e-01             nan  1.84524790e-01  2.23188331e-01
#   1.44051731e-01  1.71561079e-01  1.88216155e-01  1.33159943e-01
#   2.34365123e-01  8.57609759e-02  1.43991373e-01  2.68123003e-01
#              nan  2.39811655e-01  1.99261017e-01  1.87296475e-01
#   1.84792541e-01  1.17215088e-01  1.16008357e-01  6.79153828e-03
#   1.64558753e-01  1.28585393e-01  2.17903106e-01  1.87870870e-01
#   1.07312817e-01  4.55429007e-02  2.29208488e-01  1.97151863e-01
#   1.13283498e-01  4.35042359e-02  1.89720025e-01             nan
#   2.11095213e-01  1.45795835e-01             nan  1.92060688e-01
#   2.39086450e-01  1.12720871e-01  1.99698689e-01  4.48589971e-02
#   1.67861677e-01  4.45357634e-02             nan  2.30059255e-01
#   6.44873247e-02  1.92541306e-01  2.06509204e-01  2.40898337e-01
#   1.12583493e-01  1.91458701e-01  1.84415037e-01             nan
#   4.39762183e-02 -3.54566042e-02  2.09605379e-01  2.80474362e-01
#   1.83260057e-01             nan  2.32591471e-01  1.89792739e-01
#   6.79369732e-02  1.57443910e-01  2.20810487e-01  6.67934121e-02
#   5.56474601e-02  7.13117753e-02  1.22109890e-01  2.23757761e-01
#   2.27271104e-01  2.27954670e-01  2.73395532e-01             nan
#   2.11740786e-01  1.11852556e-01  4.37267750e-02  4.27521253e-02
#   2.27530107e-01  2.39784537e-01  4.47608204e-02  1.38394788e-01
#   1.97265123e-01 -6.50164062e-02  1.09019413e-01  1.21450916e-01
#   2.16576458e-01             nan  1.93340285e-01  6.13532817e-02
#  -6.84886014e-02  2.25130547e-01  1.95304118e-02  1.95837199e-01
#   5.16937913e-02  1.65054005e-01  5.41357252e-02  4.75032109e-02
#   1.64371469e-01  1.74865967e-01  2.39697013e-01  1.23958619e-01
#   1.39323342e-01  1.36922942e-01  1.92166958e-01  1.52935665e-01
#   1.95797918e-01  8.94111917e-02  1.88991780e-01             nan
#   1.04021661e-01  1.16334166e-01             nan  2.39425203e-01
#   2.22412226e-01  1.42902805e-01  3.04903343e-02  1.30222913e-01
#   1.64842110e-01  1.55180683e-01  4.76541630e-02             nan
#   1.70913396e-01  1.71986489e-01             nan  1.94587837e-01
#   1.24082631e-01             nan             nan  2.24809195e-01
#   2.04920884e-01  3.38445527e-02  1.61393783e-01  1.73030486e-01
#   2.36059731e-01  6.80192379e-02  1.68670515e-01  2.39578668e-01
#   1.25771971e-01  1.13611374e-01  1.34881079e-01  9.73327054e-02
#   1.87714744e-01  4.63109441e-02  1.97049986e-01             nan
#   2.26176439e-01             nan  4.58131693e-02  1.09915412e-01
#   2.17033163e-01  2.10193157e-01  2.21726806e-01  2.26531513e-01
#   4.27775622e-02  1.78731074e-01  2.28395800e-01  3.41837264e-02
#   1.31140382e-01  4.30859748e-02  2.14483365e-01             nan
#   1.39722241e-01  4.25159285e-02  2.95630026e-02  2.08219571e-01
#   2.15546492e-01  1.13900932e-01 -2.53673533e-02 -5.53369655e-02
#   4.43152468e-02  1.66920178e-01  1.91526319e-01  2.37685063e-01
#   1.22696585e-01  9.77153497e-02  1.60164978e-01  7.21046409e-02
#   4.44783099e-02  1.62291948e-01  9.09243863e-02  1.08463648e-01
#  -1.62540008e-02  1.52858670e-01             nan  9.02150529e-02
#   2.26237726e-01  2.19365342e-01  1.27221712e-01             nan
#   1.99027983e-01             nan  1.53937830e-01  9.64604431e-02
#   1.17611706e-01  1.73708760e-01  1.88076835e-01  2.27872933e-01
#   1.87174081e-01  1.46026737e-01  1.99114858e-01  1.30760993e-01
#              nan             nan  1.57720790e-01  1.87138788e-01
#              nan  4.28631091e-02  2.32894650e-01  2.26213009e-01
#   2.22598864e-01  1.70910273e-01  2.78580681e-01             nan
#   2.23334009e-01             nan  1.46014250e-01  1.33793107e-01
#   2.18906404e-01  2.48797000e-01  1.65331079e-02             nan
#              nan  1.76612978e-01             nan  1.93486493e-01
#   1.30658544e-01  2.21344991e-01  1.40338402e-01  2.37654014e-01
#   4.69401292e-02  1.40345715e-01  1.05843036e-01  1.51699201e-01
#   2.29666486e-01  1.17291111e-01  1.91013997e-01  4.99865862e-02
#   2.34166256e-01  4.82124579e-02  1.03909232e-01  4.57775193e-02
#   4.75488982e-02             nan  1.87456409e-01  1.99468200e-01
#  -5.27993595e-02             nan  1.94180819e-01  3.25850606e-02
#              nan  8.89812508e-02  2.37775143e-01  1.13745865e-01
#   2.30850162e-01             nan  2.38930114e-01  4.21284310e-02
#   5.40683390e-02  8.72373485e-02  2.23020505e-01  2.78277508e-01
#   1.72887613e-01  1.30626757e-01  1.65348021e-01  2.07383068e-02
#   2.28823681e-01  1.78532493e-01  1.98495485e-01  1.31966990e-01
#              nan  1.70094427e-01  1.09721938e-01             nan
#   8.68586205e-02  2.20708067e-01 -3.14164317e-02  8.54606128e-02
#   8.80740893e-02  1.63472281e-01  1.12728360e-01             nan
#   2.01499296e-01  1.66647710e-01  1.94728513e-01  2.32859763e-01
#   1.51013461e-01             nan  4.32983664e-02  1.63982230e-01
#   2.20037949e-01  1.99581021e-01  1.89846642e-01  1.62511737e-01
#   2.27836042e-01  2.33534672e-01  1.08539970e-01  9.18250775e-02
#   2.82501090e-01  1.94648376e-01  1.11007636e-01  4.67852677e-02
#              nan  2.36193948e-01  1.68921157e-01             nan
#   4.05549059e-02             nan  6.79742942e-02             nan
#   4.31915838e-03  1.38391116e-01  1.37815450e-01  1.66132114e-01
#   2.44062706e-01             nan  1.17433769e-01  4.27833497e-02
#   1.10664887e-01  4.68056106e-02  2.09054349e-01  1.65071501e-01
#              nan  2.17957368e-01  1.87086736e-01             nan
#   2.00751037e-01             nan  1.19609148e-01             nan
#   1.89959559e-01  1.05534922e-01  1.46415855e-01             nan
#              nan  2.74895666e-01  2.25687849e-01             nan
#   2.31429946e-01  7.33303745e-02  4.98686404e-02  1.08276938e-01
#   1.82965143e-01  4.64575759e-02  3.79517222e-02             nan
#   1.28374069e-01  1.86515343e-01  2.13965643e-01  2.21719404e-01
#  -6.10042526e-02  2.19950879e-01  1.18153124e-01  5.09203936e-02
#   7.22086942e-02  1.36050676e-02  1.17046223e-01  1.53776958e-01
#   8.49417797e-02  1.94816843e-01  1.06959627e-01  1.98372414e-01
#   1.10186806e-01  2.21522601e-01  1.94019130e-01  1.17853481e-01
#   2.41605062e-01 -7.76462998e-03  1.04880475e-01  2.22767103e-01
#   1.52894570e-01 -2.42091996e-02  4.16856046e-02  1.28031189e-01
#   2.19603317e-01  2.08181306e-01  1.81812207e-01  1.13705837e-01
#   9.10810260e-02  1.31578501e-01  2.17182496e-01  1.17827344e-01
#              nan  4.71734714e-02  2.10452115e-01  1.38108276e-01
#   1.70352184e-01  2.06758429e-01  8.13640012e-02  1.48687004e-01
#   1.94634163e-01  1.97387611e-01             nan  9.57271143e-02
#   2.25096169e-01  1.44976027e-01  5.31143378e-02 -1.04003515e-03
#   1.07071010e-01  9.65914721e-02  4.02546754e-02  9.03540175e-02
#              nan             nan  2.35094150e-01  2.13561788e-01
#   1.54518758e-01  2.41528273e-01  4.84354076e-02  8.06626443e-02
#              nan             nan  4.28166865e-02             nan
#   1.19606483e-01  1.39547887e-01  4.01438218e-02  1.40951590e-01
#              nan  2.40369296e-01  9.71176785e-02             nan
#   3.95715656e-02  2.71241462e-02  2.13630935e-01  4.70364382e-02
#   2.35429034e-01  1.97922949e-01  2.21606330e-01 -1.09128063e-01
#   9.57988523e-02  1.97644016e-01  1.74825286e-01  2.32861039e-01
#   2.32815961e-01  4.44565973e-02  1.06731662e-01  4.03368415e-02
#   2.42972337e-01  1.68466242e-01  2.30791280e-01             nan
#   1.85754489e-01             nan             nan             nan
#   1.83879967e-01  2.25672314e-01  1.10531712e-01  4.40074250e-02
#   1.63554361e-01  1.58154839e-01  2.26642543e-01  2.19417543e-01
#   1.38396663e-01  1.46697798e-01  1.84934988e-01  4.60181317e-02
#   2.13055658e-01  2.37437846e-01  1.46709278e-01  1.07882830e-01
#   3.60803241e-02  1.07937983e-01  1.55082849e-01             nan
#   1.60248659e-01  1.87731269e-01             nan  9.39453002e-02
#   2.34495651e-01             nan  1.67479112e-01  1.17427643e-01
#   1.60543230e-01  5.70472138e-02  1.19146649e-01  4.53594262e-02
#   1.90942900e-01  1.35404032e-01  6.08901793e-02             nan
#   2.37642426e-01             nan  2.34453285e-01  1.39578217e-01
#  -1.18436548e-01  2.36423894e-01  6.09467638e-02  4.27680725e-02
#   2.17170374e-01  1.83474346e-01  1.73810780e-01  9.32005376e-02]
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=1000,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 32, 55, 77, 100,
#                                                       None],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 3, 4],
#                                         'min_samples_split': [1, 2, 5, 10, 20,
#                                                               25, 50, 100],
#                                         'n_estimators': [5, 78, 152, 226, 300]},
#                    random_state=10, verbose=2)

# %%
rf_rand.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=False, max_features='sqrt', min_samples_split=5,
#                       n_estimators=78)

# %%
forest4 = RandomForestClassifier(bootstrap=False, max_features='sqrt', min_samples_split=5, n_estimators=78)
forest4.fit(xtrain_tf, ytrain)
forest4_predict = forest4.predict(xtest_tf)
results4 = metrics.classification_report(ytest, forest4_predict)

# %%
print(results4)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.63      0.67      0.65       826
#            1       0.81      0.78      0.80      1490
#
#     accuracy                           0.74      2316
#    macro avg       0.72      0.73      0.72      2316
# weighted avg       0.75      0.74      0.75      2316

# %%
#turn into pickle file to load to the interwebs
#https://towardsdatascience.com/3-ways-to-deploy-machine-learning-models-in-production-cdba15b00e
#https://ianlondon.github.io/blog/pickling-basics/


#look at streamlit.io

#also, look into additional vectorizer methods.



import pickle

filename = "my_saved_model"
pickle.dump(forest4, open(filename, 'wb+') )

filename = "my_saved_tfidf"
pickle.dump(tfidf, open(filename, 'wb+'))
